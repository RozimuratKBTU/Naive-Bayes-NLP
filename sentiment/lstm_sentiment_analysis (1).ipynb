# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import re

from tensorflow.keras.layers import Dense, LSTM, Input, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/true.txt', 'r', encoding='utf-8') as f:
    texts_true = f.readlines()
    texts_true[0] = texts_true[0].replace('\ufeff', '') #убираем первый невидимый символ

with open('/content/drive/MyDrive/train_data_false.txt', 'r', encoding='utf-8') as f:
    texts_false = f.readlines()
    texts_false[0] = texts_false[0].replace('\ufeff', '') #убираем первый невидимый символ

texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false
print(count_true, count_false, total_lines)


maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])


max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(data_pad)

print( list(tokenizer.word_index.items()) )


X = data_pad
Y = np.array([[1, 0]]*count_true + [[0, 1]]*count_false)
print(X.shape, Y.shape)

indeces = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indeces]
Y = Y[indeces]


model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length = max_text_len))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adam(0.0001))

history = model.fit(X, Y, batch_size=32, epochs=50)

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return(words)

t = "Сегодня день прекрасный".lower()
# t = "Я никогда не сяду за руль, это же смертельно опасно! ".lower()
data = tokenizer.texts_to_sequences([t])
data_pad = pad_sequences(data, maxlen=max_text_len)
print( sequence_to_text(data[0]) )

res = model.predict(data_pad)
print(res, np.argmax(res), sep='\n')
# Out:
# 988 88 1076
# [('ваш', 24), ('внутренний', 4), ('свет', 52), ('способен', 1), ('развеять', 1), ('любые', 1), ('сомнения', 1), ('с', 51), ('каждым', 4), ('новым', 2)]
# Ваш внутренний свет способен развеять любые сомнения.
#
# [[  0   0   0 ... 418 419 420]
#  [ 15 189 282 ...  63 422 125]
#  [  0   0 283 ... 126   3 285]
#  ...
#  [  0   0   0 ... 230 187   9]
#  [  0   0   0 ... 413  38  11]
#  [  0   0   0 ... 374 231 414]]
# [('вы', 1), ('ваша', 2), ('жизнь', 3), ('это', 4), ('и', 5), ('пусть', 6), ('будьте', 7), ('воплощение', 8), ('душа', 9), ('в', 10), ('не', 11), ('сердце', 12), ('свет', 13), ('источник', 14), ('с', 15), ('за', 16), ('тем', 17), ('кто', 18), ('к', 19), ('доверяйте', 20), ('живите', 21), ('улыбка', 22), ('все', 23), ('благодарны', 24), ('будут', 25), ('энергия', 26), ('творец', 27), ('дни', 28), ('ваше', 29), ('проводник', 30), ('будет', 31), ('что', 32), ('для', 33), ('ваши', 34), ('любовь', 35), ('всегда', 36), ('ваш', 37), ('жизни', 38), ('счастья', 39), ('на', 40), ('своей', 41), ('мастер', 42), ('сущность', 43), ('вас', 44), ('радости', 45), ('доказательство', 46), ('создатель', 47), ('архитектор', 48), ('только', 49), ('силы', 50), ('который', 51), ('я', 52), ('любви', 53), ('мечты', 54), ('света', 55), ('мудрости', 56), ('мир', 57), ('сила', 58), ('каждый', 59), ('живое', 60), ('пути', 61), ('своего', 62), ('себе', 63), ('вашей', 64), ('возможность', 65), ('доброты', 66), ('ключ', 67), ('реальности', 68), ('дар', 69), ('вдохновляет', 70), ('вселенной', 71), ('никогда', 72), ('день', 73), ('путь', 74), ('быть', 75), ('любовью', 76), ('brings', 77), ('себя', 78), ('творит', 79), ('судьбы', 80), ('мире', 81), ('гармония', 82), ('своих', 83), ('позитива', 84), ('подарок', 85), ('гармонии', 86), ('успеха', 87), ('дает', 88), ('наполнены', 89), ('надежды', 90), ('путешествие', 91), ('мыслей', 92), ('вам', 93), ('сад', 94), ('мысли', 95), ('счастье', 96), ('верой', 97), ('компас', 98), ('чудо', 99), ('энергии', 100), ('страстью', 101), ('исцеляет', 102), ('рост', 103), ('суперсила', 104), ('вокруг', 105), ('есть', 106), ('даже', 107), ('потенциал', 108), ('будущее', 109), ('у', 110), ('если', 111), ('стороне', 112), ('покоя', 113), ('того', 114), ('радостью', 115), ('опыт', 116), ('то', 117), ('вечный', 118), ('видит', 119), ('искусство', 120), ('настроения', 121), ('уникальности', 122), ('мне', 123), ('меня', 124), ('возможности', 125), ('делает', 126), ('как', 127), ('реальность', 128), ('души', 129), ('красоту', 130), ('его', 131), ('вселенная', 132), ('знает', 133), ('собой', 134), ('дух', 135), ('этом', 136), ('чтобы', 137), ('добра', 138), ('вдохновением', 139), ('миром', 140), ('грации', 141), ('смехом', 142), ('интуиции', 143), ('приключение', 144), ('добро', 145), ('наследие', 146), ('симфония', 147), ('другим', 148), ('миг', 149), ('эмоций', 150), ('вклад', 151), ('благодарностью', 152), ('счастью', 153), ('открыто', 154), ('океан', 155), ('отношения', 156), ('веры', 157), ('добру', 158), ('никому', 159), ('самого', 160), ('доброта', 161), ('вдохновения', 162), ('во', 163), ('а', 164), ('сердца', 165), ('лучше', 166), ('от', 167), ('она', 168), ('силой', 169), ('больше', 170), ('вашего', 171), ('приносит', 172), ('роста', 173), ('миру', 174), ('сияние', 175), ('e', 176), ('ce', 177), ('enough', 178), ('поступков', 179), ('настойчивости', 180), ('решений', 181), ('благополучия', 182), ('joy', 183), ('такой', 184), ('чем', 185), ('деньги', 186), ('денег', 187), ('внутренний', 188), ('каждым', 189), ('днем', 190), ('радость', 191), ('значит', 192), ('когда', 193), ('свою', 194), ('он', 195), ('творить', 196), ('чудеса', 197), ('же', 198), ('магнит', 199), ('внутреннего', 200), ('прекрасное', 201), ('история', 202), ('которое', 203), ('счастливым', 204), ('наполнена', 205), ('духа', 206), ('позитивных', 207), ('возможностей', 208), ('полным', 209), ('спокойствия', 210), ('зная', 211), ('щедрость', 212), ('стремится', 213), ('познание', 214), ('утешает', 215), ('сострадает', 216), ('учеба', 217), ('душам', 218), ('значимы', 219), ('мудрость', 220), ('шагам', 221), ('смелое', 222), ('неугасимый', 223), ('удивляет', 224), ('продуктивны', 225), ('со', 226), ('благодарно', 227), ('тебя', 228), ('никто', 229), ('много', 230), ('надо', 231), ('находить', 232), ('всего', 233), ('позвольте', 234), ('событий', 235), ('уже', 236), ('ее', 237), ('своему', 238), ('чудес', 239), ('стоит', 240), ('присутствие', 241), ('согревает', 242), ...
# (1076, 10) (1076, 2)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8453 - loss: 0.6406
# Epoch 2/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9311 - loss: 0.3215
# Epoch 3/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9089 - loss: 0.2537
# Epoch 4/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9190 - loss: 0.2208
# Epoch 5/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9299 - loss: 0.2080
# Epoch 6/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9313 - loss: 0.2001
# Epoch 7/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9297 - loss: 0.2134
# Epoch 8/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9403 - loss: 0.1816
# Epoch 9/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9342 - loss: 0.1893
# Epoch 10/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9405 - loss: 0.1682
# Epoch 11/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9406 - loss: 0.1383
# Epoch 12/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9551 - loss: 0.1004
# Epoch 13/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9588 - loss: 0.0832
# Epoch 14/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9714 - loss: 0.0598
# Epoch 15/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9866 - loss: 0.0456
# Epoch 16/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9938 - loss: 0.0288
# Epoch 17/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9967 - loss: 0.0247
# Epoch 18/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9986 - loss: 0.0225
# Epoch 19/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 20/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9999 - loss: 0.0142
# Epoch 21/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 22/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 23/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9986 - loss: 0.0066
# Epoch 24/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 25/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 26/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 27/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 28/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 29/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 8.5641e-04
# Epoch 30/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 7.7414e-04
# Epoch 31/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 32/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.0051e-04
# Epoch 33/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.5887e-04
# Epoch 34/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.5760e-04
# Epoch 35/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 7.3822e-04
# Epoch 36/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.6600e-04
# Epoch 37/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.0486e-04
# Epoch 38/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.9137e-04
# Epoch 39/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.5552e-04
# Epoch 40/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.4480e-04
# Epoch 41/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.0072e-04
# Epoch 42/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.3074e-04
# Epoch 43/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9783e-04
# Epoch 44/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9348e-04
# Epoch 45/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.5374e-04
# Epoch 46/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.8916e-04
# Epoch 47/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.7672e-04
# Epoch 48/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.4945e-04
# Epoch 49/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.6775e-04
# Epoch 50/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.5417e-04
# ['день']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# [[0.04454894 0.9554511 ]]
# 1
